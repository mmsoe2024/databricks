# %% [markdown]
# file full path: /Workspace/databricks MMS/My notebook
# file URL:   https://dbc-73dcddac-15dc.cloud.databricks.com/editor/notebooks/1655276021084112?o=7474657718974382

# %%
# %sql
DROP TABLE IF EXISTS emissions.default.productscsv;

# %%
# %sql
use catalog `workspace`; select * from `default`.`table_1` limit 100;

# %%
# %sql select * from workspace.default.table_2 limit 5

# %%
# %sql
select `GHG emissions mtons CO2e` from emissions.default.emissions_data limit 5

# %%
# %sql
select * from read_files('/Volumes/workspace/default/mms/testing/book2.csv') limit 2

# %%
# Export orders table to CSV
orders_df = spark.table("workspace.default.orders")
orders_df.write.mode('overwrite').option('header', True).csv("/Volumes/workspace/default/mms/orders_export")
print("Exported orders table to /Volumes/workspace/default/mms/orders_export/")

# %%
orders_count = orders_df.count()
print(orders_count)
print

# %%
# Get detailed information about spark.table method
help(spark.table)  #?spark.table

# %%
# df=spark.table("workspace.default.table_1")
df=spark.table("emissions.default.emissions_data")
display(df)

# %%
df = spark.read.csv('/Volumes/workspace/default/mms/customerscsv.csv', header=True)
display(df)

# %%
df_nyctaxi = spark.table("samples.nyctaxi.trips")
display(df_nyctaxi)

# %%
df_nyctaxi = spark.sql("SELECT * FROM samples.nyctaxi.trips")
display(df_nyctaxi)

# %%
# %sql
select * from samples.nyctaxi.trips

# %%
display(_sqldf)
