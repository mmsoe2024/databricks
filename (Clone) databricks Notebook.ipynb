# %% [markdown]
# # databricks master class
# ## turorial for pyspark builtin language
# ### hello world

# %% [markdown]
# **minn m soe**

# %%
1+6

# %%
# %sql
select('Hello world')

# %%
# ?display

# %%
data = [
    (1, "Alice", 85),
    (2, "Bob", 90),
    (3, "Charlie", 78)
]
columns = ["id", "name", "marks"]
df = spark.createDataFrame(data, columns)
display(df)

# %%
# ?spark.createDataFrame

# %%
# ?spark.read

# %%
# ?df.withColumn
